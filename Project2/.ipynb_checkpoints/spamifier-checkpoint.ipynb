# %%
import os
from pathlib import Path
import pandas as pd
import re
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.svm import SVC
from scipy.sparse import csr_matrix, hstack
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
import nltk
import time
import numpy as np

from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize

current_dir = Path(os.getcwd()).absolute()
data_dir = current_dir.joinpath('data')
file = data_dir.joinpath('spam.csv')

spam = pd.read_csv(file, encoding = 'Windows-1252')
cleanup_spam = {'v1':     {'spam': 1, 'ham': 0}}
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kyle
# [nltk_data]     Morris\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
spam = spam.replace(cleanup_spam)

# %%
spam['text'] = spam['v2']
spam['class'] = spam['v1']

data = spam.drop(['v1', 'v2'], axis = 1)

# %%
data['class'].mean()
# Out:
# 0.13406317300789664

# %%
data['len'] = [len(row) for row in data['text']]

# %%
def clean_text(text):
    
    text = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", text).split()) 
    text_tokens = word_tokenize(text)

    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
    joined_text = (" ").join(tokens_without_sw)
    clean_text.counter += 1
    if (clean_text.length - clean_text.counter) % 100 == 0:
        elapsed = time.perf_counter() - clean_text.start
        remaining = clean_text.length - clean_text.counter
        print('Row: ', remaining, ' Completion: ', clean_text.counter / clean_text.length * 100, '%')
        timeleft = remaining / clean_text.counter * elapsed
        print('Time elapsed: ', elapsed, ' seconds.\nTime remaining: ', timeleft, 'seconds.')

    return joined_text
clean_text.start = time.perf_counter()
clean_text.elapsed = 0
clean_text.counter = 0
clean_text.length = len(data)
data['text'] = data.apply(lambda row: clean_text(str(row['text'])), axis = 1)
# Out:
# Row:  5500  Completion:  1.2921751615218953 %
# Time elapsed:  7.660913400000027  seconds.
# Time remaining:  585.208662500002 seconds.
# Row:  5400  Completion:  3.086862885857861 %
# Time elapsed:  18.274699100000134  seconds.
# Time remaining:  573.7405531395391 seconds.
# Row:  5300  Completion:  4.881550610193827 %
# Time elapsed:  27.824505799999997  seconds.
# Time remaining:  542.1686791911764 seconds.
# Row:  5200  Completion:  6.676238334529792 %
# Time elapsed:  38.15828720000013  seconds.
# Time remaining:  533.3954124731201 seconds.
# Row:  5100  Completion:  8.470926058865757 %
# Time elapsed:  47.83411590000014  seconds.
# Time remaining:  516.851676038137 seconds.
# Row:  5000  Completion:  10.265613783201722 %
# Time elapsed:  57.66393170000015  seconds.
# Time remaining:  504.05534702797337 seconds.
# Row:  4900  Completion:  12.060301507537687 %
# Time elapsed:  66.24285740000005  seconds.
# Time remaining:  483.0208352083337 seconds.
# Row:  4800  Completion:  13.854989231873654 %
# Time elapsed:  76.10108220000006  seconds.
# Time remaining:  473.16735046632164 seconds.
# Row:  4700  Completion:  15.649676956209618 %
# Time elapsed:  86.54139850000001  seconds.
# Time remaining:  466.450198337156 seconds.
# Row:  4600  Completion:  17.444364680545586 %
# Time elapsed:  96.41028180000012  seconds.
# Time remaining:  456.2626504938277 seconds.
# Row:  4500  Completion:  19.23905240488155 %
# Time elapsed:  105.57265910000001  seconds.
# Time remaining:  443.1688115205224 seconds.
# Row:  4400  Completion:  21.033740129217517 %
# Time elapsed:  116.84563849999995  seconds.
# Row:  2000  Completion:  64.1062455132807 %
# Time elapsed:  353.6665134000002  seconds.
# Time remaining:  198.02156405375152 seconds.
# Row:  1900  Completion:  65.90093323761666 %
# Time elapsed:  362.7491265000001  seconds.
# Time remaining:  187.69698811274515 seconds.
# Row:  1800  Completion:  67.69562096195261 %
# Time elapsed:  371.88250570000014  seconds.
# Time remaining:  177.46248946447514 seconds.
# Row:  1700  Completion:  69.49030868628859 %
# Time elapsed:  382.01685870000006  seconds.
# Time remaining:  167.72434395402897 seconds.
# Row:  1600  Completion:  71.28499641062454 %
# Time elapsed:  390.84756330000005  seconds.
# Time remaining:  157.4411131117825 seconds.
# Row:  1500  Completion:  73.07968413496052 %
# Time elapsed:  400.5127282000001  seconds.
# Time remaining:  147.53661402259334 seconds.
# Row:  1400  Completion:  74.87437185929649 %
# Time elapsed:  411.3681236  seconds.
# Time remaining:  138.0429944966443 seconds.
# Row:  1300  Completion:  76.66905958363245 %
# Time elapsed:  420.7910340000001  seconds.
# Time remaining:  128.04970603932588 seconds.
# Row:  1200  Completion:  78.46374730796842 %
# Time elapsed:  431.06945199999996  seconds.
# Time remaining:  118.31732442817932 seconds.
# Row:  1100  Completion:  80.25843503230438 %
# Time elapsed:  441.8453178000002  seconds.
# Time remaining:  108.682882285331 seconds.
# Row:  1000  Completion:  82.05312275664033 %
# Time elapsed:  452.89085480000017  seconds.
# Time remaining:  99.05749230096242 seconds.
# Row:  900  Completion:  83.84781048097632 %
# Time elapsed:  463.36775980000016  seconds.
# Time remaining:  89.26176879708906 seconds.
# Row:  800  Completion:  85.64249820531228 %
# Time elapsed:  473.1545974000003  seconds.
# Time remaining:  79.32181012573349 seconds.
# Row:  700  Completion:  87.43718592964824 %
# Time elapsed:  483.7321948000001  seconds.
# Time remaining:  69.5017521264368 seconds.
# Row:  600  Completion:  89.23187365398421 %
# Time elapsed:  496.5042070000002  seconds.
# Time remaining:  59.91603463395014 seconds.
# Row:  500  Completion:  91.02656137832017 %
# Time elapsed:  505.84781369999996  seconds.
# Time remaining:  49.86670087736593 seconds.
# Row:  400  Completion:  92.82124910265614 %
# Time elapsed:  516.2151178000001  seconds.
# Time remaining:  39.92382968290798 seconds.
# Row:  300  Completion:  94.61593682699211 %
# Time elapsed:  525.6153581000001  seconds.
# Time remaining:  29.9098269025038 seconds.
# Row:  200  Completion:  96.41062455132807 %
# Time elapsed:  534.7494873000003  seconds.
# Time remaining:  19.908767211466873 seconds.
# Row:  100  Completion:  98.20531227566404 %
# Time elapsed:  543.2811118000002  seconds.
# Time remaining:  9.928382891081874 seconds.
# Row:  0  Completion:  100.0 %
# Time elapsed:  553.2036876  seconds.
# Time remaining:  0.0 seconds.

# %%
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['class'], random_state=0)

# %%
spamdata = data[data['class'] == 1]
nonspamdata = data[data['class'] == 0]

spamlength = spamdata['len'].mean()
nonspamlength = nonspamdata['len'].mean()

# %%
data['class'].value_counts()
# Out:
# 0    4825
# 1     747
# Name: class, dtype: int64

# %%
spam_list = spamdata['text'].tolist()
spam_string = ""
for row in spam_list:
    spam_string += row

spam_string = spam_string.lower()
spam_string = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " 
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(max_font_size = 160, margin=0, background_color = "white", colormap="Reds").generate(spam_string)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(max_font_size = 160, margin=0, background_color = "white", colormap="Reds").generate(nonspam_string)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
print('rows in test set: ' + str(X_test.shape))
print('rows in train set: ' + str(X_train.shape))
# Out:
# rows in test set: (1393,)
# rows in train set: (4179,)

# %%
xlist = X_train.tolist()
vectorizer = TfidfVectorizer(
    input= xlist)

features_train_transformed = vectorizer.fit_transform(xlist) 
features_test_transformed  = vectorizer.transform(X_test)

# %%
classifier = MultinomialNB()
classifier.fit(features_train_transformed, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print('Multinomial NB accuracy: ', classifier.score(features_test_transformed, y_test) * 100, '%')
# Out:
# Multinomial NB accuracy:  96.33883704235463 %

# %%
test_labels = classifier.predict(features_test_transformed)

actuals = y_test.tolist()
predictions = test_labels
labels = ['spam', 'ham']

results = confusion_matrix(actuals, predictions)

# %%
print(results)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(results)
plt.title('Confusion matrix of the spam classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[1196    0]
#  [  51  146]]

# %%
print ('Accuracy Score :',accuracy_score(actuals, predictions))
print ('Report : ')
print (classification_report(actuals, predictions) )
score_2 = f1_score(actuals, predictions, average = 'binary')
print('F-Measure: %.3f' % score_2)
# Out:
# Accuracy Score : 0.9633883704235463
# Report :
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1196
#            1       1.00      0.74      0.85       197
#
#    micro avg       0.96      0.96      0.96      1393
#    macro avg       0.98      0.87      0.92      1393
# weighted avg       0.96      0.96      0.96      1393
#
# F-Measure: 0.851

# %%
def add_feature(X, feature):


    return hstack([X, csr_matrix(feature).T], 'csr')
vectorizer = TfidfVectorizer(min_df=5, ngram_range=[1,3])
X_train_transformed = vectorizer.fit_transform(X_train)
X_train_transformed_with_length = add_feature(X_train_transformed, [X_train.str.len(),
                                                                    X_train.apply(lambda x: len(''.join([a for a in x if a.isdigit()])))])

X_test_transformed = vectorizer.transform(X_test)
X_test_transformed_with_length = add_feature(X_test_transformed, [X_test.str.len(),
                                                                  X_test.apply(lambda x: len(''.join([a for a in x if a.isdigit()])))])

# %%
log = LogisticRegression(C = 100)

log.fit(X_train_transformed_with_length, y_train)

y_predicted = log.predict(X_test_transformed_with_length)

roc_auc_score(y_test, y_predicted)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9666167258034396

# %%
results = confusion_matrix(y_test, y_predicted)
print(results)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(results)
plt.title('Confusion matrix of the spam classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[1189    7]
#  [  12  185]]

# %%
print ('Accuracy Score :',accuracy_score(y_test, y_predicted))
print ('Report : ')
print (classification_report(y_test, y_predicted) )
score_2 = f1_score(y_test, y_predicted, average = 'binary')
print('F-Measure: %.3f' % score_2)
# Out:
# Accuracy Score : 0.9863603732950467
# Report :
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1196
#            1       0.96      0.94      0.95       197
#
#    micro avg       0.99      0.99      0.99      1393
#    macro avg       0.98      0.97      0.97      1393
# weighted avg       0.99      0.99      0.99      1393
#
# F-Measure: 0.951
